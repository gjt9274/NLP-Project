# %% [markdown]
# ## 1. 任务介绍
# > 介绍任务的基本内容，以及问题的公式化
# ---
# 文本分类是自然语言处理中最基础的任务之一，主要是通过分类器将给定的文本划分到特定的类，比如情绪分类、垃圾邮件分类、电影评论分类等。具体任务公式化如下：
# $$
# \begin{aligned}
# 文本 ： &X = (x_1,x_2,\dots,x_n) \\
# 类标签 ：& Y = (y_1,y_2,\dots,y_n)\\
# 模型 ：& f: x_i  \xrightarrow{f} y_i, \hspace{1em} i = 1,2, \dots,n
# \end{aligned}
# $$
# 本文选用Kaggle的电影评论情感分析来作为任务。

# %% [markdown]
# ## 2.环境准备

# %%
import re
import numpy as np
import pandas as pd

from bs4 import BeautifulSoup

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics 

import nltk
from nltk.corpus import stopwords

# %% [markdown]
# ## 3. 数据预处理
# > 需要对数据进行清洗
# ---
#
# 处理步骤大致如下：
#     1. 去除html标签
#     2. 去除标点
#     3. 切分成词
#     4. 去除停用词
#     5. 重组为新的句子

# %%
# 0. 先准备数据
file_path = '../data/IMDB/labeledTrainData.tsv'
df = pd.read_csv(file_path,sep='\t',escapechar='\\')
print('Number of samples:{}'.format(len(df)))
df.head()
# Out:
# Number of samples:25000
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  "The Classic War of the Worlds" by Timothy Hin...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...

# %%
eng_stopwords = stopwords.words('english') #定义停用词

def text_clean(text):
    text = BeautifulSoup(text,'html.parser').get_text() #去除html标签
    text = re.sub(r'[^a-zA-Z]',' ',text) #去除标点
    words = text.lower().split()  #全部转成小写，然后按空格分词
    words = [w for w in words if w not in eng_stopwords] #去除停用词
    return ' '.join(words)  #重组成新的句子

df['clean_review'] = df.review.apply(text_clean)
df.head()
# Out:
#        id  sentiment                                             review  \
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  "The Classic War of the Worlds" by Timothy Hin...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...
#
#                                         clean_review
# 0  stuff going moment mj started listening music ...
# 1  classic war worlds timothy hines entertaining ...
# 2  film starts manager nicholas bell giving welco...
# 3  must assumed praised film greatest filmed oper...
# 4  superbly trashy wondrously unpretentious explo...

# %% [markdown]
# ## 4. 文本特征表示
# > 文本向量化，并提取特征，分为离散法和分布式法(此处主要讲离散法)
# ---
# 离散法主要有以下几种方法：
#  1. 词袋模型(Bag of word): 用单词频数来表示文本，不考虑文本的语法结构和单词顺序
#  2. 独热编码(One-hot): 将文本表示成整个词标长度的向量，出现过的词为1，否则为0
#  3. n元语法(n-gram): 对词袋模型的一种改进，即用n个词或词组组成的字符串作为特征，然后再用词袋模型的方法将文本表示为向量形式
#  4. TF-IDF： 用词的TF-IDF来表示文本
#
# <span style="color:red">注：其实上述方法都可以看作是词袋模型</span>

# %%
# 1. 使用统计词频，作为文本特征
vectorizer_feq = CountVectorizer(max_features=5000) #取词频为前5000的词
train_freq = vectorizer_feq.fit_transform(df.clean_review).toarray()
print("词频为特征的文本-单词矩阵维度:",train_freq.shape)

# 2. 使用bigram，作为文本特征
vectorizer_bigram = CountVectorizer(ngram_range=(2,2),max_features=1000,token_pattern=r'\b\w+\b', min_df=1)
# analyze = vectorizer_bigram.build_analyzer()
# print("bi-gram示例：",analyze(df.clean_review[0]))#bi-gram举例
train_bigram = vectorizer_bigram.fit_transform(df.clean_review).toarray()
print("bi-gram为特征的文本-单词矩阵维度：",train_bigram.shape)

# 2. 使用tfidf, 作为文本特征
vectorizer_tfidf = TfidfVectorizer(max_features=5000)
train_tfidf = vectorizer_tfidf.fit_transform(df.clean_review).toarray()

print("TF-IDF为特征的文本-单词矩阵维度：",train_tfidf.shape)
# Out:
# 词频为特征的文本-单词矩阵维度: (25000, 5000)
# bi-gram为特征的文本-单词矩阵维度： (25000, 1000)
# TF-IDF为特征的文本-单词矩阵维度： (25000, 5000)

# %% [markdown]
# ## 5. 辅助函数
# > 包括数据批量生成器，softmax函数，预测函数，评估函数

# %%
#定义数据批量生成器
def batch_generator(data, batch_size, shuffle=True):
    X, Y = data
    n_samples = X.shape[0]
    indices = np.arange(n_samples)
    if shuffle:
        np.random.shuffle(indices)  #打乱顺序

    for start in range(0, n_samples, batch_size):
        end = min(start + batch_size, n_samples)
        batch_idx = indices[start:end]

        yield X[batch_idx], Y[batch_idx]
        
# softmax函数
def softmax(scores):
    sum_exp = np.sum(np.exp(scores),axis=1,keepdims=True)
    softmax = np.exp(scores) / sum_exp
    return softmax

# 预测函数
def predict(w,b,x):
    scores = np.dot(x,w.T) + b
    probs = softmax(scores)
    
    return np.argmax(probs,axis=1).reshape(-1,1)
    
# 评估函数，包括精确率，召回率和F1值
def evaluate(w,val_x,val_y):
    val_loss = []
    val_gen = batch_generator((val_x,val_y),batch_size=32,shuffle=False)
    for batch_x,batch_y in val_gen:
        scores = np.dot(batch_x,w.T)
        prob = softmax(scores)

        y_one_hot = one_hot(batch_y)
        # 损失函数
        loss = - (1.0 / len(batch_x)) * np.sum(y_one_hot * np.log(prob))
        val_loss.append(loss)
        
    return np.mean(val_loss)
    
    
def one_hot(batch_y,n_classes=2):
    n = batch_y.shape[0]
    one_hot = np.zeros((n, n_classes))
    one_hot[np.arange(n), batch_y.T] = 1
    return one_hot

# %% [markdown]
# ## 6. 构建分类器
# > 此处以softmax regression作为分类器

# %%
def logistic_regression(x, y, n_classes=2, lr = 0.001, val_split=0.2, batch_size=64, epochs=1000, early_stop=None):
    n_samples,n_features = x.shape

    w = np.random.rand(n_classes, n_features)
    train_all_loss = []
    val_all_loss = []
    not_improved = 0
    best_val_loss = np.inf
    best_w = None

    indices = np.random.permutation(n_samples)
    split = int(n_samples * (1-val_split))
    training_idx = indices[:split]
    valid_idx = indices[split+1:]
    
    train_x = x[training_idx]
    train_y = y[training_idx]
    
    valid_x = x[valid_idx]
    valid_y = y[valid_idx]
    
    for epoch in range(epochs):
        training_gen = batch_generator((train_x, train_y), batch_size=64)
        train_loss = []
        for batch_x, batch_y in training_gen:
            scores = np.dot(batch_x, w.T)
            prob = softmax(scores)

            y_one_hot = one_hot(batch_y,n_classes)
            # 损失函数
            loss = - (1.0 / len(batch_x)) * np.sum(y_one_hot * np.log(prob))
            train_loss.append(loss)

            # 梯度下降
            dw = -(1.0/len(batch_x)) * np.dot((y_one_hot - prob).T, batch_x)
            w = w - lr * dw

        val_loss = evaluate(w, valid_x, valid_y)

        print("Epoch = {0},the train loss = {1:.4f}, the val loss = {2:.4f}".format(
            epoch, np.mean(train_loss), val_loss))

        train_all_loss.append(np.mean(train_loss))
        val_all_loss.append(val_loss)

        if early_stop is not None:
            if val_loss <= best_val_loss:
                best_val_loss = val_loss
                best_w = w
                not_improved = 0
            else:
                not_improved += 1

            if not_improved > early_stop:
                printnt("Validation performance didn\'t improve for {} epochs. "
                        "Training stops.".format(early_stop))
                break
                
    return best_w,train_all_loss,val_all_loss

# %% [markdown]
# ## 7.训练

# %% [markdown]
# ### 7.1 以BOW为特征进行训练

# %%
label = df['sentiment'].values
w,train_all_loss,val_all_loss = logistic_regression(train_freq,label,early_stop=10)
# Out:
# Epoch = 0,the train loss = 1.9454, the val loss = 1.8243
# Epoch = 1,the train loss = 1.7821, the val loss = 1.7350
# Epoch = 2,the train loss = 1.7172, the val loss = 1.6801
# Epoch = 3,the train loss = 1.6640, the val loss = 1.6335
# Epoch = 4,the train loss = 1.6172, the val loss = 1.5910
# Epoch = 5,the train loss = 1.5757, the val loss = 1.5515
# Epoch = 6,the train loss = 1.5354, the val loss = 1.5150
# Epoch = 7,the train loss = 1.5000, the val loss = 1.4809
# Epoch = 8,the train loss = 1.4644, the val loss = 1.4492
# Epoch = 9,the train loss = 1.4325, the val loss = 1.4196
# Epoch = 10,the train loss = 1.4019, the val loss = 1.3917
# Epoch = 11,the train loss = 1.3731, the val loss = 1.3658
# Epoch = 12,the train loss = 1.3477, the val loss = 1.3414
# Epoch = 13,the train loss = 1.3213, the val loss = 1.3185
# Epoch = 14,the train loss = 1.2970, the val loss = 1.2968
# Epoch = 15,the train loss = 1.2754, the val loss = 1.2764
# Epoch = 16,the train loss = 1.2537, the val loss = 1.2573
# Epoch = 17,the train loss = 1.2344, the val loss = 1.2390
# Epoch = 18,the train loss = 1.2157, the val loss = 1.2216
# Epoch = 19,the train loss = 1.1971, the val loss = 1.2052
# Epoch = 20,the train loss = 1.1805, the val loss = 1.1895
# Epoch = 21,the train loss = 1.1647, the val loss = 1.1747
# Epoch = 22,the train loss = 1.1472, the val loss = 1.1606
# Epoch = 23,the train loss = 1.1334, the val loss = 1.1471
# Epoch = 24,the train loss = 1.1182, the val loss = 1.1342
# Epoch = 25,the train loss = 1.1042, the val loss = 1.1219
# Epoch = 26,the train loss = 1.0912, the val loss = 1.1102
# Epoch = 27,the train loss = 1.0788, the val loss = 1.0989
# Epoch = 28,the train loss = 1.0664, the val loss = 1.0881
# Epoch = 29,the train loss = 1.0561, the val loss = 1.0777
# Epoch = 30,the train loss = 1.0442, the val loss = 1.0677
# Epoch = 31,the train loss = 1.0334, the val loss = 1.0581
# Epoch = 32,the train loss = 1.0234, the val loss = 1.0488
# Epoch = 33,the train loss = 1.0131, the val loss = 1.0398
# Epoch = 34,the train loss = 1.0032, the val loss = 1.0312
# Epoch = 35,the train loss = 0.9943, the val loss = 1.0229
# Epoch = 36,the train loss = 0.9858, the val loss = 1.0150
# Epoch = 37,the train loss = 0.9770, the val loss = 1.0072
# Epoch = 38,the train loss = 0.9679, the val loss = 0.9997
# Epoch = 39,the train loss = 0.9604, the val loss = 0.9924
# Epoch = 40,the train loss = 0.9523, the val loss = 0.9854
# Epoch = 41,the train loss = 0.9443, the val loss = 0.9786
# Epoch = 42,the train loss = 0.9364, the val loss = 0.9720
# Epoch = 43,the train loss = 0.9289, the val loss = 0.9656
# Epoch = 44,the train loss = 0.9219, the val loss = 0.9594
# Epoch = 45,the train loss = 0.9164, the val loss = 0.9534
# Epoch = 46,the train loss = 0.9090, the val loss = 0.9475
# Epoch = 47,the train loss = 0.9025, the val loss = 0.9418
# Epoch = 48,the train loss = 0.8957, the val loss = 0.9363
# Epoch = 49,the train loss = 0.8900, the val loss = 0.9309
# Epoch = 50,the train loss = 0.8839, the val loss = 0.9256
# Epoch = 51,the train loss = 0.8787, the val loss = 0.9204
# Epoch = 52,the train loss = 0.8719, the val loss = 0.9154
# Epoch = 53,the train loss = 0.8666, the val loss = 0.9106
# Epoch = 54,the train loss = 0.8620, the val loss = 0.9058
# Epoch = 55,the train loss = 0.8552, the val loss = 0.9011
# Epoch = 56,the train loss = 0.8506, the val loss = 0.8965
# Epoch = 57,the train loss = 0.8450, the val loss = 0.8921
# Epoch = 58,the train loss = 0.8396, the val loss = 0.8877
# Epoch = 59,the train loss = 0.8352, the val loss = 0.8834
# Epoch = 60,the train loss = 0.8303, the val loss = 0.8793
# Epoch = 61,the train loss = 0.8257, the val loss = 0.8752
# Epoch = 62,the train loss = 0.8208, the val loss = 0.8712
# Epoch = 63,the train loss = 0.8162, the val loss = 0.8673
# Epoch = 64,the train loss = 0.8121, the val loss = 0.8634
# Epoch = 65,the train loss = 0.8074, the val loss = 0.8597
# Epoch = 66,the train loss = 0.8030, the val loss = 0.8560
# Epoch = 67,the train loss = 0.7992, the val loss = 0.8524
# Epoch = 68,the train loss = 0.7942, the val loss = 0.8488
# Epoch = 69,the train loss = 0.7909, the val loss = 0.8453
# Epoch = 70,the train loss = 0.7865, the val loss = 0.8419
# Epoch = 71,the train loss = 0.7832, the val loss = 0.8385
# Epoch = 72,the train loss = 0.7784, the val loss = 0.8353
# Epoch = 73,the train loss = 0.7757, the val loss = 0.8321
# Epoch = 74,the train loss = 0.7714, the val loss = 0.8288
# Epoch = 75,the train loss = 0.7670, the val loss = 0.8258
# Epoch = 76,the train loss = 0.7635, the val loss = 0.8226
# Epoch = 77,the train loss = 0.7606, the val loss = 0.8196
# Epoch = 78,the train loss = 0.7570, the val loss = 0.8166
# Epoch = 79,the train loss = 0.7531, the val loss = 0.8136
# Epoch = 80,the train loss = 0.7498, the val loss = 0.8108
# Epoch = 81,the train loss = 0.7467, the val loss = 0.8080
# Epoch = 82,the train loss = 0.7431, the val loss = 0.8051
# Epoch = 83,the train loss = 0.7399, the val loss = 0.8023
# Epoch = 84,the train loss = 0.7363, the val loss = 0.7996
# Epoch = 85,the train loss = 0.7332, the val loss = 0.7969
# Epoch = 86,the train loss = 0.7295, the val loss = 0.7943
# Epoch = 87,the train loss = 0.7283, the val loss = 0.7917
# Epoch = 88,the train loss = 0.7238, the val loss = 0.7891
# Epoch = 89,the train loss = 0.7206, the val loss = 0.7866
# Epoch = 90,the train loss = 0.7180, the val loss = 0.7841
# Epoch = 91,the train loss = 0.7147, the val loss = 0.7817
# Epoch = 92,the train loss = 0.7126, the val loss = 0.7792
# Epoch = 93,the train loss = 0.7093, the val loss = 0.7768
# Epoch = 94,the train loss = 0.7072, the val loss = 0.7744
# Epoch = 95,the train loss = 0.7040, the val loss = 0.7722
# Epoch = 96,the train loss = 0.7008, the val loss = 0.7698
# Epoch = 97,the train loss = 0.6979, the val loss = 0.7676
# Epoch = 98,the train loss = 0.6955, the val loss = 0.7653
# Epoch = 99,the train loss = 0.6930, the val loss = 0.7631
# Epoch = 100,the train loss = 0.6901, the val loss = 0.7609
# Epoch = 101,the train loss = 0.6874, the val loss = 0.7588
# Epoch = 102,the train loss = 0.6846, the val loss = 0.7567
# Epoch = 103,the train loss = 0.6823, the val loss = 0.7545
# Epoch = 104,the train loss = 0.6800, the val loss = 0.7524
# Epoch = 105,the train loss = 0.6773, the val loss = 0.7504
# Epoch = 106,the train loss = 0.6744, the val loss = 0.7483
# Epoch = 107,the train loss = 0.6727, the val loss = 0.7463
# Epoch = 108,the train loss = 0.6698, the val loss = 0.7443
# Epoch = 109,the train loss = 0.6671, the val loss = 0.7424
# Epoch = 110,the train loss = 0.6644, the val loss = 0.7404
# Epoch = 111,the train loss = 0.6631, the val loss = 0.7385
# Epoch = 112,the train loss = 0.6604, the val loss = 0.7367
# Epoch = 113,the train loss = 0.6582, the val loss = 0.7348
# Epoch = 114,the train loss = 0.6552, the val loss = 0.7329
# Epoch = 115,the train loss = 0.6532, the val loss = 0.7311
# Epoch = 116,the train loss = 0.6513, the val loss = 0.7293
# Epoch = 117,the train loss = 0.6496, the val loss = 0.7275
# Epoch = 118,the train loss = 0.6477, the val loss = 0.7257
# Epoch = 119,the train loss = 0.6449, the val loss = 0.7240
# Epoch = 120,the train loss = 0.6422, the val loss = 0.7222
# Epoch = 121,the train loss = 0.6400, the val loss = 0.7205
# Epoch = 122,the train loss = 0.6380, the val loss = 0.7188
# Epoch = 123,the train loss = 0.6360, the val loss = 0.7172
# Epoch = 124,the train loss = 0.6341, the val loss = 0.7155
# Epoch = 125,the train loss = 0.6324, the val loss = 0.7138
# Epoch = 126,the train loss = 0.6304, the val loss = 0.7122
# Epoch = 127,the train loss = 0.6281, the val loss = 0.7106
# Epoch = 128,the train loss = 0.6263, the val loss = 0.7090
# Epoch = 129,the train loss = 0.6244, the val loss = 0.7074
# Epoch = 130,the train loss = 0.6217, the val loss = 0.7059
# Epoch = 131,the train loss = 0.6205, the val loss = 0.7043
# Epoch = 132,the train loss = 0.6183, the val loss = 0.7028
# Epoch = 133,the train loss = 0.6172, the val loss = 0.7012
# Epoch = 134,the train loss = 0.6152, the val loss = 0.6997
# Epoch = 135,the train loss = 0.6129, the val loss = 0.6983
# Epoch = 136,the train loss = 0.6111, the val loss = 0.6968
# Epoch = 137,the train loss = 0.6094, the val loss = 0.6953
# Epoch = 138,the train loss = 0.6078, the val loss = 0.6939
# Epoch = 139,the train loss = 0.6052, the val loss = 0.6925
# Epoch = 140,the train loss = 0.6045, the val loss = 0.6910
# Epoch = 141,the train loss = 0.6021, the val loss = 0.6896
# Epoch = 142,the train loss = 0.5998, the val loss = 0.6882
# Epoch = 143,the train loss = 0.5991, the val loss = 0.6869
# Epoch = 144,the train loss = 0.5968, the val loss = 0.6855
# Epoch = 145,the train loss = 0.5950, the val loss = 0.6841
# Epoch = 146,the train loss = 0.5930, the val loss = 0.6828
# Epoch = 147,the train loss = 0.5924, the val loss = 0.6815
# Epoch = 148,the train loss = 0.5900, the val loss = 0.6802
# Epoch = 149,the train loss = 0.5883, the val loss = 0.6789
# Epoch = 150,the train loss = 0.5873, the val loss = 0.6776
# Epoch = 151,the train loss = 0.5852, the val loss = 0.6763
# Epoch = 152,the train loss = 0.5832, the val loss = 0.6750
# Epoch = 153,the train loss = 0.5813, the val loss = 0.6737
# Epoch = 154,the train loss = 0.5806, the val loss = 0.6725
# Epoch = 155,the train loss = 0.5790, the val loss = 0.6713
# Epoch = 156,the train loss = 0.5773, the val loss = 0.6700
# Epoch = 157,the train loss = 0.5756, the val loss = 0.6688
# Epoch = 158,the train loss = 0.5743, the val loss = 0.6676
# Epoch = 159,the train loss = 0.5726, the val loss = 0.6664
# Epoch = 160,the train loss = 0.5708, the val loss = 0.6652
# Epoch = 161,the train loss = 0.5696, the val loss = 0.6640
# Epoch = 162,the train loss = 0.5686, the val loss = 0.6629
# Epoch = 163,the train loss = 0.5665, the val loss = 0.6617
# Epoch = 164,the train loss = 0.5650, the val loss = 0.6606
# Epoch = 165,the train loss = 0.5639, the val loss = 0.6594
# Epoch = 166,the train loss = 0.5623, the val loss = 0.6583
# Epoch = 167,the train loss = 0.5607, the val loss = 0.6572
# Epoch = 168,the train loss = 0.5599, the val loss = 0.6561
# Epoch = 169,the train loss = 0.5579, the val loss = 0.6550
# Epoch = 170,the train loss = 0.5561, the val loss = 0.6539
# Epoch = 171,the train loss = 0.5558, the val loss = 0.6528
# Epoch = 172,the train loss = 0.5539, the val loss = 0.6517
# Epoch = 173,the train loss = 0.5523, the val loss = 0.6507
# Epoch = 174,the train loss = 0.5513, the val loss = 0.6496
# Epoch = 175,the train loss = 0.5493, the val loss = 0.6486
# Epoch = 176,the train loss = 0.5485, the val loss = 0.6475
# Epoch = 177,the train loss = 0.5471, the val loss = 0.6465
# Epoch = 178,the train loss = 0.5459, the val loss = 0.6455
# Epoch = 179,the train loss = 0.5440, the val loss = 0.6444
# Epoch = 180,the train loss = 0.5424, the val loss = 0.6434
# Epoch = 181,the train loss = 0.5419, the val loss = 0.6424
# Epoch = 182,the train loss = 0.5405, the val loss = 0.6414
# Epoch = 183,the train loss = 0.5388, the val loss = 0.6405
# Epoch = 184,the train loss = 0.5380, the val loss = 0.6395
# Epoch = 185,the train loss = 0.5373, the val loss = 0.6385
# Epoch = 186,the train loss = 0.5358, the val loss = 0.6375
# Epoch = 187,the train loss = 0.5342, the val loss = 0.6366
# Epoch = 188,the train loss = 0.5325, the val loss = 0.6356
# Epoch = 189,the train loss = 0.5325, the val loss = 0.6347
# Epoch = 190,the train loss = 0.5304, the val loss = 0.6338
# Epoch = 191,the train loss = 0.5294, the val loss = 0.6328
# Epoch = 192,the train loss = 0.5289, the val loss = 0.6319
# Epoch = 193,the train loss = 0.5273, the val loss = 0.6310
# Epoch = 194,the train loss = 0.5256, the val loss = 0.6301
# Epoch = 195,the train loss = 0.5252, the val loss = 0.6292
# Epoch = 196,the train loss = 0.5241, the val loss = 0.6283
# Epoch = 197,the train loss = 0.5224, the val loss = 0.6274
# Epoch = 198,the train loss = 0.5218, the val loss = 0.6265
# Epoch = 199,the train loss = 0.5205, the val loss = 0.6256
# Epoch = 200,the train loss = 0.5191, the val loss = 0.6248
# Epoch = 201,the train loss = 0.5178, the val loss = 0.6239
# Epoch = 202,the train loss = 0.5165, the val loss = 0.6230
# Epoch = 203,the train loss = 0.5158, the val loss = 0.6222
# Epoch = 204,the train loss = 0.5147, the val loss = 0.6213
# Epoch = 205,the train loss = 0.5133, the val loss = 0.6205
# Epoch = 206,the train loss = 0.5122, the val loss = 0.6197
# Epoch = 207,the train loss = 0.5111, the val loss = 0.6188
# Epoch = 208,the train loss = 0.5102, the val loss = 0.6180
# Epoch = 209,the train loss = 0.5088, the val loss = 0.6172
# Epoch = 210,the train loss = 0.5081, the val loss = 0.6164
# Epoch = 211,the train loss = 0.5072, the val loss = 0.6156
# Epoch = 212,the train loss = 0.5057, the val loss = 0.6148
# Epoch = 213,the train loss = 0.5044, the val loss = 0.6140
# Epoch = 214,the train loss = 0.5040, the val loss = 0.6132
# Epoch = 215,the train loss = 0.5026, the val loss = 0.6124
# Epoch = 216,the train loss = 0.5017, the val loss = 0.6116
# Epoch = 217,the train loss = 0.5012, the val loss = 0.6109
# Epoch = 218,the train loss = 0.4997, the val loss = 0.6101
# Epoch = 219,the train loss = 0.4985, the val loss = 0.6093
# Epoch = 220,the train loss = 0.4980, the val loss = 0.6086
